# %%
import pandas as pd

# %% [markdown]
# # Loading datasets

# %%
players = pd.read_csv('datasets/2016_atletas.csv')
teams = pd.read_csv('datasets/2016_clubes.csv')
scouts = pd.read_csv('datasets/2016_scouts.csv')
positions = pd.read_csv("datasets/posicoes.csv")

# %% [markdown]
# # Renaming column names to make it easier when merging dataframes

# %%
players.rename(columns={'apelido':'name', 'clube_id':'team_id', 'posicao_id':'position_id'}, inplace=True)
teams.rename(columns={'id':'team_id', 'nome':'team', 'abreviacao':'team_abbrev', 'slug':'team_slug'}, inplace=True)
positions.rename(columns={'id':'position_id', 'nome':'position', 'abreviacao':'position_abbrev'}, inplace=True)

scouts = scouts[['atleta_id', 'pontos_num', 'clube_id']]
scouts.rename(columns={'atleta_id':'id', 'pontos_num':'points', 'clube_id':'team_id'}, inplace=True)

# %%
players.head()
# Out:
#       id          name  team_id  position_id
# 0  89258        Daniel      262            1
# 1  68873  Paulo Victor      262            1
# 2  79066  Alex Muralha      262            1
# 3  91194        Thiago      262            1
# 4  38109     Jefferson      263            1

# %%
teams.head()
# Out:
#    team_id         team team_abbrev    team_slug
# 0      262     Flamengo         FLA     Flamengo
# 1      263     Botafogo         BOT     Botafogo
# 2      264  Corinthians         COR  Corinthians
# 3      266   Fluminense         FLU   Fluminense
# 4      275    Palmeiras         PAL    Palmeiras

# %%
positions.head()
# Out:
#    position_id  position position_abbrev
# 0            1   Goleiro             gol
# 1            2   Lateral             lat
# 2            3  Zagueiro             zag
# 3            4      Meia             mei
# 4            5  Atacante             ata

# %%
scouts.head()
# Out:
#       id  points  team_id
# 0  50301     0.0    262.0
# 1  36540     0.0    262.0
# 2  68685     0.0    262.0
# 3  68711     0.0    262.0
# 4  88065     0.0    262.0

# %% [markdown]
# # Aggregating points per player for the season

# %%
points = scouts.groupby(['id'], as_index=False).points.sum()
points.rename(columns={'pontos':'points'}, inplace=True)

# %%
points.head()
# Out:
#       id  points
# 0  36540    32.3
# 1  36591     0.0
# 2  36612    81.4
# 3  36650    48.3
# 4  36856    32.0

# %% [markdown]
# # Merging dataframes into players

# %%
players = pd.merge(players, points, on='id', how='outer')
players = pd.merge(players, positions, on='position_id', how='outer')
players = pd.merge(players, teams, on='team_id', how='outer')

# %%
players.head()
# Out:
#       id          name  team_id  position_id  points position position_abbrev  \
# 0  89258        Daniel      262            1     0.0  Goleiro             gol
# 1  68873  Paulo Victor      262            1    37.4  Goleiro             gol
# 2  79066  Alex Muralha      262            1   153.0  Goleiro             gol
# 3  91194        Thiago      262            1     0.0  Goleiro             gol
# 4  95861  Thiago Ennes      262            2     0.0  Lateral             lat
#
#        team team_abbrev team_slug
# 0  Flamengo         FLA  Flamengo
# 1  Flamengo         FLA  Flamengo
# 2  Flamengo         FLA  Flamengo
# 3  Flamengo         FLA  Flamengo
# 4  Flamengo         FLA  Flamengo

# %%
players.nlargest(10, 'points')
# Out:
#         id              name  team_id  position_id  points  position  \
# 582  68952           Marinho      287            5   211.0  Atacante
# 282  62121         Vanderlei      277            1   189.3   Goleiro
# 407  87863        Arrascaeta      283            4   183.7      Meia
# 6    88065             Jorge      262            2   176.7   Lateral
# 299  87552       Vitor Bueno      277            4   171.8      Meia
# 995  86485              Keno      344            5   169.4  Atacante
# 612  68911       Diego Souza      292            4   167.0      Meia
# 160  87999    Gustavo Scarpa      266            4   164.3      Meia
# 693  50284            Wilson      294            1   164.2   Goleiro
# 150  71892  Wellington Silva      266            2   157.9   Lateral
#
#     position_abbrev        team team_abbrev   team_slug
# 582             ata     Vitória         VIT     Vitoria
# 282             gol      Santos         SAN      Santos
# 407             mei    Cruzeiro         CRU    Cruzeiro
# 6               lat    Flamengo         FLA    Flamengo
# 299             mei      Santos         SAN      Santos
# 995             ata  Santa Cruz         SCZ  Santa-Cruz
# 612             mei       Sport         SPT       Sport
# 160             mei  Fluminense         FLU  Fluminense
# 693             gol    Coritiba         CFC    Coritiba
# 150             lat  Fluminense         FLU  Fluminense

# %%
players.nsmallest(10, 'points')
# Out:
#         id              name  team_id  position_id  points  position  \
# 471  86754  Guilherme Amorim      284            4    -8.8      Meia
# 962  84847       Luan Peres       344            3    -7.9  Zagueiro
# 589  71724            Agenor      292            1    -7.6   Goleiro
# 981  86527  Wellington Cézar      344            4    -6.8      Meia
# 302  37917             Elano      277            4    -6.5      Meia
# 506  82613        Alan Costa      285            3    -6.2  Zagueiro
# 789  37788     Marcelo Boeck      315            1    -5.9   Goleiro
# 189  78151            Vagner      275            1    -5.4   Goleiro
# 17   82403     César Martins      262            3    -4.6  Zagueiro
# 766  71719             Elton      303            4    -4.2      Meia
#
#     position_abbrev           team team_abbrev      team_slug
# 471             mei         Grêmio         GRE         Gremio
# 962             zag     Santa Cruz         SCZ     Santa-Cruz
# 589             gol          Sport         SPT          Sport
# 981             mei     Santa Cruz         SCZ     Santa-Cruz
# 302             mei         Santos         SAN         Santos
# 506             zag  Internacional         INT  Internacional
# 789             gol    Chapecoense         CHA    Chapecoense
# 189             gol      Palmeiras         PAL      Palmeiras
# 17              zag       Flamengo         FLA       Flamengo
# 766             mei    Ponte Preta         PON    Ponte-Preta

# %%
# to be continued...
